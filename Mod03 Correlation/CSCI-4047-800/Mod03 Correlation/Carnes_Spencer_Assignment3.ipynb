# %% [markdown]
# # Assignment 3
#
# ### Instructions
# 1. Import the following modules:
#     - `pandas`
#     - `stats` from `scipy`
# 2. Create a dataframe from the data contained in *income_data.csv* using `pandas`

# %%
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt

df = pd.read_csv('./Income Data.csv')
print(df)
# Out:
#                    job  type  income  education  prestige
# 0           accountant  prof      62         86        82
# 1                pilot  prof      72         76        83
# 2            architect  prof      75         92        90
# 3               author  prof      55         90        76
# 4              chemist  prof      64         86        90
# 5             minister  prof      21         84        87
# 6            professor  prof      64         93        93
# 7              dentist  prof      80        100        90
# 8             reporter    wc      67         87        52
# 9             engineer  prof      72         86        88
# 10          undertaker  prof      42         74        57
# 11              lawyer  prof      76         98        89
# 12           physician  prof      76         97        97
# 13      welfare.worker  prof      41         84        59
# 14             teacher  prof      48         91        73
# 15           conductor    wc      76         34        38
# 16          contractor  prof      53         45        76
# 17       factory.owner  prof      60         56        81
# 18       store.manager  prof      42         44        45
# 19              banker  prof      78         82        92
# 20          bookkeeper    wc      29         72        39
# 21        mail.carrier    wc      48         55        34
# 22     insurance.agent    wc      55         71        41
# 23         store.clerk    wc      29         50        16
# 24           carpenter    bc      21         23        33
# 25         electrician    bc      47         39        53
# 26         RR.engineer    bc      81         28        67
# 27           machinist    bc      36         32        57
# 28      auto.repairman    bc      22         22        26
# 29             plumber    bc      44         25        29
# 30   gas.stn.attendant    bc      15         29        10
# 31          coal.miner    bc       7          7        15
# 32  streetcar.motorman    bc      42         26        19
# 33         taxi.driver    bc       9         19        10
# 34        truck.driver    bc      21         15        13
# 35    machine.operator    bc      21         20        24
# 36              barber    bc      16         26        20
# 37           bartender    bc      16         28         7
# 38         shoe.shiner    bc       9         17         3
# 39                cook    bc      14         22        16
# 40          soda.clerk    bc      12         30         6
# 41            watchman    bc      17         25        11
# 42             janitor    bc       7         20         8
# 43           policeman    bc      34         47        41
# 44              waiter    bc       8         32        10

# %% [markdown]
# 3. Calculate and display Pearson's **correlation coefficients** and the **p-values** for *income* and *education*

# %%
print('Income & Education')
r, p = stats.pearsonr(df.income, df.education)
print(f'r (Pearson correlation coefficient): {r:.3f}')
print(f'p-value:                             {p:.3f}')

plt.scatter(x=df['income'], y = df['education'], alpha=0.3)
plt.show()
# Out:
# Income & Education
# r (Pearson correlation coefficient): 0.725
# p-value:                             0.000

# %% [markdown]
# 3. Calculate and display Pearson's **correlation coefficients** and the **p-values** for *income* and *prestige*

# %%
# bpm & released month
print('Income & Prestige')
r, p = stats.pearsonr(df.income, df.prestige)
print(f'r (Pearson correlation coefficient): {r:.3f}')
print(f'p-value:                             {p:.3f}')

plt.scatter(x=df['income'], y = df['prestige'], alpha=0.3)
plt.show()
# Out:
# Income & Prestige
# r (Pearson correlation coefficient): 0.838
# p-value:                             0.000

# %% [markdown]
# 4. Calculate and display Pearson's **correlation coefficients** and the **p-values** for *education* and *prestige*

# %%
# bpm & released month
print('Education & Prestige')
r, p = stats.pearsonr(df.education, df.prestige)
print(f'r (Pearson correlation coefficient): {r:.3f}')
print(f'p-value:                             {p:.3f}')

plt.scatter(x=df['education'], y = df['prestige'], alpha=0.3)
plt.show()
# Out:
# Education & Prestige
# r (Pearson correlation coefficient): 0.852
# p-value:                             0.000

# %% [markdown]
# 5. In the empty `Markdown` cell below, explain the following for **each of the calculated correlation coefficients**
#     - The **strength** and **direction** of the correlation
#     - The **statistical significance** of the test (**p-value**); emphasize if we can trust the correlation test or not, and why

# %% [markdown]
# Income and education: The strength and direction of the correlation is moderately strong, being 0.725, with a positive trend. The p-value was less than 0.05 meaning that there was almost no way this data is only this strong by chance, so it can be trusted.
#
# Income and prestige: The strength and direction of the correlation is strong, being 0.838, with a positive trend. The p-value was less than 0.05 meaning that there was almost no way this data is only this strong by chance, so it can be trusted.
#
# Education and prestige: The strength and direction of the correlation is strong, being 0.852, with a positive trend. The p-value was less than 0.05 meaning that there was almost no way this data is only this strong by chance, so it can be trusted.

# %% [markdown]
# In the empty `Markdown` cell below, answer the following question:
#
# 6. Pearson's correlation coefficient OR covariance can both be used to measure the direction of the relationship between two variables (e.g., education and income). Explain why Pearson's correlation coefficient may be better than covariance.

# %% [markdown]
# Pearson's correlation coefficient may be better because it is standardized, meaning that it is easier to tell if the number given is high or low without more knowledge or context.

# %% [markdown]
# 7. Submit this `Jupyter` file to D2L, renamed as **Last_First_Assignment3.ipynb**
#     - Replace '**Last**' and '**First**' with your name
